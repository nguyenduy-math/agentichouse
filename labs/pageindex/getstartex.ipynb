# %%
# 7f8082b1c48440508ace9d0442d40355

# %%
pip install -U pageindex

# %%
from pageindex import PageIndexClient
 
pi_client = PageIndexClient(api_key="7f8082b1c48440508ace9d0442d40355")

# %%
tree_result = pi_client.get_tree("pi-cmpffqjj900a001pd8xhh4ysu")["result"]

# %%
tree_result

# %%
# Chat with a specific document
response = pi_client.chat_completions(
    messages=[
        {"role": "user", "content": "Bạn có thông tin phúc lợi gì trong công ty không?"}
    ],
    doc_id="pi-cmpffqjj900a001pd8xhh4ysu"
)
 
print(response["choices"][0]["message"]["content"])
# Out:
# Dưới đây là tổng hợp chính sách phúc lợi và đãi ngộ tại **Công ty TNHH Agentic House Việt Nam** (áp dụng từ 01/03/2024):
#
# ---
#
# ## 💰 1. Lương & Thu nhập
# - **Lương cơ bản** theo hợp đồng + các phụ cấp:
#   - Phụ cấp trách nhiệm: 3–10% (từ Trưởng nhóm trở lên)
#   - Phụ cấp điện thoại: 300k–500k/tháng
#   - Phụ cấp xăng xe: 500k/tháng
# - **Thang lương tham khảo:**
#   | Cấp bậc | Lương (triệu/tháng) |
#   |---|---|
#   | Junior | 8 – 15 |
#   | Senior | 15 – 25 |
#   | Team Lead | 22 – 35 |
#   | Manager | 30 – 50 |
#   | Phó GĐ | 45 – 70 |
# - **Tăng lương** 2 lần/năm (tháng 6 & 12): tối thiểu 5%, xuất sắc được 10–15%.
#
# ---
#
# ## 🎁 2. Thưởng
# - **Thưởng hiệu suất** (tháng 7 & tháng 1):
#   - Xuất sắc: 2 tháng lương | Tốt: 1 tháng | Đạt: 0,5 tháng
# - **Thưởng Tết**: ≥ 1 tháng lương (trên 1 năm), tính tỷ lệ nếu dưới 1 năm.
# - **Thưởng dự án**: 5–20 triệu/dự án vượt KPI; sáng kiến: 1–5 triệu.
#
# ---
#
# ## 🏥 3. Bảo hiểm
# ...
